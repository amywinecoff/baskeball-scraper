# %%
from basketball_reference_scraper.teams import get_roster
from basketball_reference_scraper.players import get_stats 
from ratelimit import limits, RateLimitException, sleep_and_retry

# %%
import pandas as pd
from requests import get
from bs4 import BeautifulSoup
import time
import os
import numpy as np
import csv
import glob

# %%
try:
    from constants import TEAM_TO_TEAM_ABBR, TEAM_SETS
    from utils import remove_accents
except:
    from basketball_reference_scraper.constants import TEAM_TO_TEAM_ABBR, TEAM_SETS
    from basketball_reference_scraper.utils import remove_accents

# %%
# 30 calls per minute
CALLS = 1
RATE_LIMIT = 60

@sleep_and_retry
@limits(calls=CALLS, period=RATE_LIMIT)
def check_limit():
    ''' Empty function just to check for calls to API '''
    return

# %%
os.getcwd()
# Out:
# '/Users/amywinecoff/Documents/CITP/Research/Github/ml-teaching/basketball_reference_scraper'

# %%
def get_roster(team, season_end_year):
    check_limit()
    r = get(
        f'https://www.basketball-reference.com/teams/{team}/{season_end_year}.html')
    df = None
    
    try:
    #if r.status_code == 200:
        soup = BeautifulSoup(r.content, 'html.parser')
        table = soup.find('table')
        df = pd.read_html(str(table))[0]
        df.columns = ['NUMBER', 'PLAYER', 'POS', 'HEIGHT', 'WEIGHT', 'BIRTH_DATE',
                      'NATIONALITY', 'EXPERIENCE', 'COLLEGE']
        # remove rows with no player name (this was the issue above)
        df = df[df['PLAYER'].notna()]
        df['PLAYER'] = df['PLAYER'].apply(
            lambda name: remove_accents(name, team, season_end_year))
        # handle rows with empty fields but with a player name.
        df['BIRTH_DATE'] = df['BIRTH_DATE'].apply(
            lambda x: pd.to_datetime(x) if pd.notna(x) else pd.NaT)
        df['NATIONALITY'] = df['NATIONALITY'].apply(
            lambda x: x.upper() if pd.notna(x) else '')
    except Exception as e:
        print(e)
        print(r.status_code)

    return df

# %%
RUN_ROSTER = False

if RUN_ROSTER:
    season_end = 2021
    nba_teams = ['ATL','BOS','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC',
    'LAL','MEM','MIA','MIL','MIN','NOH','NYK','BKN','OKC','ORL','PHI','PHO','POR','SAC',
    'SAS','TOR','UTH','WAS']
    failed_teams = []

    players_positions = []
    for team in nba_teams:
        print(f'Current team: {team}')
        #don't regenerate the file if it is already there
        if not os.path.exists(f'./data/team_roster_{team}_{season_end}.csv'):
            try:
                team_roster = get_roster(team=team, season_end_year=2021)
                team_roster['TEAM']= team
                team_roster.to_csv(f'./data/team_roster_{team}_{season_end}.csv', index=False)
                roster_subset = team_roster[['PLAYER', 'POS', 'TEAM']].values.tolist()
                players_positions.append(roster_subset)
                time.sleep(180)

            except Exception as e:
                print(team)
                print(e)
                failed_teams.append(team)

# %%
WRITE_PLAYERS_FILE=False
if WRITE_PLAYERS_FILE:
    nba_teams = ['ATL','BOS','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC',
        'LAL','MEM','MIA','MIL','MIN','NOH','NYK','BKN','OKC','ORL','PHI','PHO','POR','SAC',
        'SAS','TOR','UTH','WAS']
    season_end = 2021
    players_positions = []
    for team in nba_teams:

        if os.path.exists(f'./data/team_roster_{team}_{season_end}.csv'):
            team_roster = pd.read_csv(f'./data/team_roster_{team}_{season_end}.csv')
            roster_subset = team_roster[['PLAYER', 'POS', 'TEAM']].values.tolist()
            players_positions.extend(roster_subset)


    players_positions_df =pd.DataFrame(players_positions, columns=['player', 'position', 'team'])
    players_positions_df.to_csv('./data/all_players_positions.csv', index=False)

# %%
def fetch_player_career(player):
    career = get_stats(player, stat_type='PER_GAME', playoffs=False, career=False, ask_matches=False)
    
    # Drop rows containing 'Did Not Play' by only returning rows with digits in the "Games Played" field
    career_stats = career[career['G'].apply(lambda x: str(x).replace('.','').isdigit())]
    
    return career_stats

def extract_stats(career_stats):

    total_seasons = len(career_stats)
    
    career_ast = (sum(career_stats['AST'].astype(float)) / total_seasons)
    career_stl = (sum(career_stats['STL'].astype(float)) / total_seasons)
    career_blk = (sum(career_stats['BLK'].astype(float)) / total_seasons)
    career_tov = (sum(career_stats['TOV'].astype(float)) / total_seasons)
    career_pf = (sum(career_stats['PF'].astype(float)) / total_seasons)
    career_pts = (sum(career_stats['PTS'].astype(float)) / total_seasons)

    
    return [career_ast, career_stl, career_blk, career_tov, career_pf, career_pts]

# %%
players_positions_df = pd.read_csv('./data/all_players_positions.csv')
players_positions_df.head()


careers = []
columns = ['ast','stl','blk','tov','pf','pts', 'name', 'position', 'team']

failed_players = []

for index, row in players_positions_df.iterrows():
    
    #don't regenerate the file if it is already there
    player_name = row['player'].replace(" ",'_')
    print(f'Current player: {player_name}')
    if not os.path.exists(f'./data/players/{player_name}_stats.csv'):
        try:
            d = fetch_player_career(row['player'])
            bball_features = extract_stats(d)
            #add the player name, position, and team
            bball_features.extend([row['player'], row['position'], row['team']])

            bball_df = pd.DataFrame(np.array(bball_features).reshape(-1,len(bball_features)), columns=columns)
            bball_df.head()
            bball_df.to_csv(f'./data/players/{player_name}_stats.csv', index=False)

            time.sleep(30)

        except Exception as e:
            print(row['player'])
            print(e)
            failed_players.append(row['player'])
# Out:
# Current player: Bogdan_Bogdanović
# Current player: Clint_Capela
# Clint Capela
# string index out of range
# Current player: John_Collins
# Current player: Kris_Dunn
# Current player: Bruno_Fernando
# Current player: Danilo_Gallinari
# Current player: Brandon_Goodwin
# Current player: Solomon_Hill
# Current player: Kevin_Huerter
# Current player: De'Andre_Hunter
# Current player: Nathan_Knight
# Current player: Skylar_Mays
# Current player: Onyeka_Okongwu
# Current player: Cam_Reddish
# Current player: Rajon_Rondo
# Current player: Tony_Snell
# Current player: Lou_Williams
# Current player: Trae_Young
# Current player: Jaylen_Brown
# Current player: Carsen_Edwards
# Current player: Tacko_Fall
# Current player: Evan_Fournier
# Current player: Javonte_Green
# Current player: Luke_Kornet
# Current player: Romeo_Langford
# Current player: Aaron_Nesmith
# Current player: Semi_Ojeleye
# Current player: Jabari_Parker
# Current player: Payton_Pritchard
# Current player: Marcus_Smart
# Current player: Jayson_Tatum
# Current player: Jeff_Teague
# Current player: Daniel_Theis
# Current player: Tristan_Thompson
# Current player: Moritz_Wagner
# Current player: Kemba_Walker
# Current player: Tremont_Waters
# Current player: Grant_Williams
# Current player: Robert_Williams
# Current player: Al-Farouq_Aminu
# Current player: Ryan_Arcidiacono
# Current player: Troy_Brown_Jr.
# Current player: Wendell_Carter_Jr.
# Current player: Devon_Dotson
# Current player: Cristiano_Felício
# Current player: Daniel_Gafford
# Current player: Javonte_Green
# Current player: Chandler_Hutchison
# Current player: Luke_Kornet
# Current player: Zach_LaVine
# Current player: Lauri_Markkanen
# Current player: Adam_Mokoka
# Current player: Otto_Porter_Jr.
# Current player: Tomáš_Satoranský
# Current player: Garrett_Temple
# Current player: Daniel_Theis
# Current player: Denzel_Valentine
# Current player: Nikola_Vučević
# Current player: Coby_White
# Current player: Patrick_Williams
# Current player: Thaddeus_Young
# Current player: Jarrett_Allen
# Current player: Marques_Bolden
# Current player: Quinn_Cook
# Current player: Matthew_Dellavedova
# Current player: Damyean_Dotson
# Current player: Andre_Drummond
# Current player: Dante_Exum
# Current player: Yogi_Ferrell
# Current player: Darius_Garland
# Current player: Isaiah_Hartenstein
# Current player: Mfiondu_Kabengele
# Current player: Kevin_Love
# Current player: Thon_Maker
# Current player: Jeremiah_Martin
# Current player: JaVale_McGee
# Current player: Larry_Nance_Jr.
# Current player: Isaac_Okoro
# Current player: Cedi_Osman
# Cedi Osman
# string index out of range
# Current player: Taurean_Prince
# Current player: Collin_Sexton
# Current player: Lamar_Stevens
# Current player: Brodric_Thomas
# Current player: Anderson_Varejão
# Current player: Dean_Wade
# Current player: Dylan_Windler
# Current player: Tyler_Bey
# Current player: Jalen_Brunson
# Current player: Trey_Burke
# Current player: Willie_Cauley-Stein
# Current player: Luka_Dončić
# Current player: Dorian_Finney-Smith
# Current player: Josh_Green
# Current player: Tim_Hardaway_Jr.
# Current player: Nate_Hinton
# Current player: Wes_Iwundu
# Wes Iwundu
# 'G'
# Current player: James_Johnson
# Current player: Maxi_Kleber
# Maxi Kleber
# string index out of range
# Current player: Boban_Marjanović
# Current player: Nicolò_Melli
# Current player: Kristaps_Porziņģis
# Current player: Dwight_Powell
# Current player: J.J._Redick
# J.J. Redick
# string index out of range
# Current player: Josh_Richardson
# Current player: Tyrell_Terry
# Current player: Will_Barton
# Current player: Bol_Bol
# Current player: Facundo_Campazzo
# Current player: Vlatko_Čančar
# Current player: Gary_Clark
# Current player: PJ_Dozier
# Current player: Aaron_Gordon
# Current player: JaMychal_Green
# Current player: R.J._Hampton
# R.J. Hampton
# string index out of range
# Current player: Gary_Harris
# Current player: Shaquille_Harrison
# Current player: Isaiah_Hartenstein
# Current player: Markus_Howard
# Current player: Nikola_Jokić
# Current player: JaVale_McGee
# Current player: Paul_Millsap
# Current player: Monte_Morris
# Current player: Jamal_Murray
# Current player: Zeke_Nnaji
# Current player: Michael_Porter_Jr.
# Current player: Austin_Rivers
# Current player: Greg_Whittington
# Greg Whittington
# list index out of range
# Current player: Saddiq_Bey
# Current player: Tyler_Cook
# Current player: Hamidou_Diallo
# Current player: Sekou_Doumbouya
# Current player: Wayne_Ellington
# Current player: Jerami_Grant
# Current player: Blake_Griffin
# Current player: Killian_Hayes
# Current player: Frank_Jackson
# Current player: Josh_Jackson
# Current player: Cory_Joseph
# Current player: Saben_Lee
# Current player: Rodney_McGruder
# Current player: Svi_Mykhailiuk
# Svi Mykhailiuk
# list index out of range
# Current player: Jahlil_Okafor
# Current player: Mason_Plumlee
# Current player: Derrick_Rose
# Current player: Deividas_Sirvydis
# Current player: Dennis_Smith_Jr.
# Current player: Isaiah_Stewart
# Current player: Delon_Wright
# Current player: Kent_Bazemore
# Current player: Jordan_Bell
# Current player: Marquese_Chriss
# Current player: Stephen_Curry
# Current player: Draymond_Green
# Current player: Damion_Lee
# Current player: Kevon_Looney
# Current player: Nico_Mannion
# Current player: Mychal_Mulder
# Current player: Kelly_Oubre_Jr.
# Current player: Eric_Paschall
# Current player: Gary_Payton_II
# Current player: Jordan_Poole
# Current player: Alen_Smailagić
# Current player: Juan_Toscano-Anderson
# Current player: Brad_Wanamaker
# Current player: Andrew_Wiggins
# Current player: James_Wiseman
# Current player: D.J._Augustin
# D.J. Augustin
# string index out of range
# Current player: Avery_Bradley
# Current player: Armoni_Brooks
# Current player: Sterling_Brown
# Current player: Bruno_Caboclo
# Current player: DeMarcus_Cousins
# Current player: Eric_Gordon
# Current player: James_Harden
# Current player: Danuel_House_Jr.
# Current player: DaQuan_Jeffries
# Current player: Mason_Jones
# Current player: Rodions_Kurucs
# Current player: Anthony_Lamb
# Current player: Kenyon_Martin_Jr.
# Current player: Ben_McLemore
# Current player: David_Nwaba
# Current player: Victor_Oladipo
# Current player: Cameron_Oliver
# Cameron Oliver
# list index out of range
# Current player: Kelly_Olynyk
# Current player: Justin_Patton
# Current player: Kevin_Porter_Jr.
# Current player: Cameron_Reynolds
# Current player: Ray_Spalding
# Current player: Jae'Sean_Tate
# Jae'Sean Tate
# list index out of range
# Current player: Brodric_Thomas
# Current player: Khyri_Thomas
# Current player: P.J._Tucker
# P.J. Tucker
# string index out of range
# Current player: John_Wall
# Current player: D.J._Wilson
# D.J. Wilson
# string index out of range
# Current player: Christian_Wood
# Current player: Goga_Bitadze
# Current player: Brian_Bowen
# Current player: Amida_Brimah
# Amida Brimah
# list index out of range
# Current player: Oshae_Brissett
# Current player: Malcolm_Brogdon
# Current player: Aaron_Holiday
# Current player: Justin_Holiday
# Current player: Jeremy_Lamb
# Current player: Jalen_Lecque
# Current player: Caris_LeVert
# Current player: Kelan_Martin
# Current player: T.J._McConnell
# T.J. McConnell
# string index out of range
# Current player: Doug_McDermott
# Current player: Victor_Oladipo
# Current player: Domantas_Sabonis
# Current player: JaKarr_Sampson
# Current player: Cassius_Stanley
# Current player: Edmond_Sumner
# Current player: Myles_Turner
# Current player: T.J._Warren
# T.J. Warren
# string index out of range
# Current player: Nicolas_Batum
# Current player: Patrick_Beverley
# Current player: Amir_Coffey
# Current player: DeMarcus_Cousins
# Current player: Yogi_Ferrell
# Current player: Malik_Fitts
# Current player: Paul_George
# Current player: Serge_Ibaka
# Current player: Reggie_Jackson
# Current player: Mfiondu_Kabengele
# Current player: Luke_Kennard
# Current player: Kawhi_Leonard
# Current player: Terance_Mann
# Current player: Marcus_Morris
# Current player: Daniel_Oturu
# Current player: Patrick_Patterson
# Current player: Rajon_Rondo
# Current player: Jay_Scrubb
# Current player: Lou_Williams
# Current player: Ivica_Zubac
# Current player: Kostas_Antetokounmpo
# Current player: Devontae_Cacok
# Current player: Kentavious_Caldwell-Pope
# Current player: Alex_Caruso
# Current player: Quinn_Cook
# Current player: Anthony_Davis
# Current player: Andre_Drummond
# Current player: Jared_Dudley
# Current player: Marc_Gasol
# Current player: Montrezl_Harrell
# Current player: Talen_Horton-Tucker
# Current player: LeBron_James
# Current player: Damian_Jones
# Current player: Kyle_Kuzma
# Current player: Wesley_Matthews
# Current player: Alfonzo_McKinnie
# Current player: Ben_McLemore
# Current player: Markieff_Morris
# Current player: Dennis_Schröder
# Current player: Grayson_Allen
# Current player: Kyle_Anderson
# Current player: Desmond_Bane
# Current player: Dillon_Brooks
# Current player: Brandon_Clarke
# Current player: Gorgui_Dieng
# Current player: Tim_Frazier
# Current player: Jaren_Jackson_Jr.
# Current player: Tyus_Jones
# Current player: John_Konchar
# Current player: Sean_McDermott
# Current player: De'Anthony_Melton
# Current player: Ja_Morant
# Current player: Jontay_Porter
# Current player: Killian_Tillie
# Current player: Xavier_Tillman_Sr.
# Current player: Jonas_Valančiūnas
# Current player: Justise_Winslow
# Current player: Precious_Achiuwa
# Current player: Bam_Adebayo
# Current player: Trevor_Ariza
# Current player: Nemanja_Bjelica
# Current player: Avery_Bradley
# Current player: Jimmy_Butler
# Current player: Dewayne_Dedmon
# Current player: Goran_Dragić
# Current player: Maurice_Harkless
# Current player: Udonis_Haslem
# Current player: Tyler_Herro
# Current player: Andre_Iguodala
# Current player: Meyers_Leonard
# Current player: Kendrick_Nunn
# Current player: KZ_Okpala
# Current player: Victor_Oladipo
# Current player: Kelly_Olynyk
# Current player: Duncan_Robinson
# Current player: Chris_Silva
# Current player: Max_Strus
# Current player: Gabe_Vincent
# Current player: Jaylen_Adams
# Current player: Giannis_Antetokounmpo
# Current player: Thanasis_Antetokounmpo
# Current player: D.J._Augustin
# D.J. Augustin
# string index out of range
# Current player: Elijah_Bryant
# Elijah Bryant
# list index out of range
# Current player: Pat_Connaughton
# Current player: Torrey_Craig
# Current player: Mamadi_Diakite
# Current player: Donte_DiVincenzo
# Current player: Bryn_Forbes
# Current player: Jrue_Holiday
# Current player: Justin_Jackson
# Current player: Rodions_Kurucs
# Current player: Brook_Lopez
# Current player: Sam_Merrill
# Current player: Khris_Middleton
# Current player: Jordan_Nwora
# Current player: Bobby_Portis
# Current player: Jeff_Teague
# Current player: Axel_Toupane
# Current player: P.J._Tucker
# P.J. Tucker
# string index out of range
# Current player: D.J._Wilson
# D.J. Wilson
# string index out of range
# Current player: Malik_Beasley
# Current player: Jarrett_Culver
# Current player: Ed_Davis
# Current player: Anthony_Edwards
# Current player: Ashton_Hagans
# Current player: Juancho_Hernangómez
# Juancho Hernangómez
# 'G'
# Current player: Jake_Layman
# Current player: Jaden_McDaniels
# Current player: Jordan_McLaughlin
# Current player: Jaylen_Nowell
# Current player: Josh_Okogie
# Current player: Naz_Reid
# Current player: Ricky_Rubio
# Current player: D'Angelo_Russell
# D'Angelo Russell
# string index out of range
# Current player: Karl-Anthony_Towns
# Current player: Jarred_Vanderbilt
# Current player: RJ_Barrett
# Current player: Ignas_Brazdeikis
# Current player: Reggie_Bullock
# Current player: Alec_Burks
# Current player: Taj_Gibson
# Current player: Jared_Harper
# Current player: Kevin_Knox
# Current player: Nerlens_Noel
# Current player: Frank_Ntilikina
# Frank Ntilikina
# string index out of range
# Current player: Elfrid_Payton
# Current player: Norvel_Pelle
# Current player: Theo_Pinson
# Current player: Immanuel_Quickley
# Current player: Julius_Randle
# Current player: Austin_Rivers
# Current player: Mitchell_Robinson
# Current player: Derrick_Rose
# Current player: Dennis_Smith_Jr.
# Current player: Obi_Toppin
# Current player: Darius_Bazley
# Current player: Tony_Bradley
# Current player: Charlie_Brown_Jr.
# Current player: Moses_Brown
# Current player: Gabriel_Deck
# Gabriel Deck
# list index out of range
# Current player: Hamidou_Diallo
# Current player: Luguentz_Dort
# Current player: Shai_Gilgeous-Alexander
# Current player: Josh_Hall
# Current player: George_Hill
# Current player: Jaylen_Hoard
# Current player: Al_Horford
# Current player: Justin_Jackson
# Current player: Ty_Jerome
# Current player: Théo_Maledon
# Current player: Darius_Miller
# Current player: Mike_Muscala
# Current player: Svi_Mykhailiuk
# Svi Mykhailiuk
# list index out of range
# Current player: Aleksej_Pokusevski
# Current player: Justin_Robinson
# Current player: Isaiah_Roby
# Current player: Kenrich_Williams
# Current player: Al-Farouq_Aminu
# Current player: Cole_Anthony
# Current player: Dwayne_Bacon
# Current player: Mo_Bamba
# Mo Bamba
# 'STL'
# Current player: Khem_Birch
# Current player: Jordan_Bone
# Current player: Ignas_Brazdeikis
# Current player: Devin_Cannady
# Current player: Wendell_Carter_Jr.
# Current player: Michael_Carter-Williams
# Current player: Gary_Clark
# Current player: James_Ennis_III
# Current player: Evan_Fournier
# Current player: Robert_Franks
# Current player: Markelle_Fultz
# Current player: Aaron_Gordon
# Current player: Donta_Hall
# Current player: R.J._Hampton
# R.J. Hampton
# string index out of range
# Current player: Gary_Harris
# Current player: Karim_Mané
# Current player: Frank_Mason_III
# Current player: Chuma_Okeke
# Current player: Otto_Porter_Jr.
# Current player: Chasson_Randle
# Current player: Terrence_Ross
# Current player: Sindarius_Thornwell
# Current player: Nikola_Vučević
# Current player: Moritz_Wagner
# Current player: Tony_Bradley
# Current player: Ignas_Brazdeikis
# Current player: Gary_Clark
# Current player: Seth_Curry
# Current player: Joel_Embiid
# Current player: Terrance_Ferguson
# Current player: Danny_Green
# Current player: Tobias_Harris
# Current player: George_Hill
# Current player: Dwight_Howard
# Current player: Isaiah_Joe
# Current player: Mason_Jones
# Current player: Furkan_Korkmaz
# Current player: Dakota_Mathias
# Dakota Mathias
# list index out of range
# Current player: Tyrese_Maxey
# Current player: Shake_Milton
# Current player: Vincent_Poirier
# Current player: Paul_Reed
# Current player: Mike_Scott
# Current player: Ben_Simmons
# Current player: Matisse_Thybulle
# Current player: Anthony_Tolliver
# Current player: Rayjon_Tucker
# Current player: Ty-Shon_Alexander
# Current player: Deandre_Ayton
# Current player: Devin_Booker
# Current player: Mikal_Bridges
# Current player: Jevon_Carter
# Current player: Torrey_Craig
# Current player: Jae_Crowder
# Current player: Langston_Galloway
# Current player: Cameron_Johnson
# Current player: Damian_Jones
# Current player: Frank_Kaminsky
# Current player: E'Twaun_Moore
# E'Twaun Moore
# string index out of range
# Current player: Abdel_Nader
# Current player: Chris_Paul
# Current player: Cameron_Payne
# Current player: Dario_Šarić
# Current player: Jalen_Smith
# Current player: Carmelo_Anthony
# Current player: Keljin_Blevins
# Current player: Robert_Covington
# Current player: CJ_Elleby
# Current player: Enes_Freedom
# Enes Freedom
# list index out of range
# Current player: Harry_Giles
# Current player: Rondae_Hollis-Jefferson
# Current player: Rodney_Hood
# Current player: Derrick_Jones_Jr.
# Current player: T.J._Leaf
# T.J. Leaf
# string index out of range
# Current player: Damian_Lillard
# Current player: Nassir_Little
# Current player: CJ_McCollum
# Current player: Jusuf_Nurkić
# Current player: Norman_Powell
# Current player: Anfernee_Simons
# Current player: Gary_Trent_Jr.
# Current player: Marvin_Bagley_III
# Current player: Harrison_Barnes
# Current player: Nemanja_Bjelica
# Current player: Terence_Davis
# Current player: De'Aaron_Fox
# Current player: Kyle_Guy
# Current player: Tyrese_Haliburton
# Current player: Maurice_Harkless
# Current player: Buddy_Hield
# Current player: Richaun_Holmes
# Current player: Justin_James
# Current player: DaQuan_Jeffries
# Current player: Damian_Jones
# Current player: Cory_Joseph
# Current player: Louis_King
# Current player: Chimezie_Metu
# Current player: Jabari_Parker
# Current player: Norvel_Pelle
# Current player: Jahmi'us_Ramsey
# Current player: Glenn_Robinson_III
# Current player: Chris_Silva
# Current player: Hassan_Whiteside
# Current player: Robert_Woodard_II
# Current player: Delon_Wright
# Current player: LaMarcus_Aldridge
# Current player: Keita_Bates-Diop
# Current player: DeMar_DeRozan
# Current player: Gorgui_Dieng
# Current player: Drew_Eubanks
# Current player: Rudy_Gay
# Current player: Keldon_Johnson
# Current player: Tre_Jones
# Current player: Trey_Lyles
# Current player: Patty_Mills
# Current player: Dejounte_Murray
# Current player: Jakob_Poeltl
# Current player: Cameron_Reynolds
# Current player: Luka_Šamanić
# Current player: Devin_Vassell
# Current player: Lonnie_Walker_IV
# Current player: Quinndary_Weatherspoon
# Current player: Derrick_White
# Current player: OG_Anunoby
# Current player: Aron_Baynes
# Current player: DeAndre'_Bembry
# Current player: Khem_Birch
# Current player: Chris_Boucher
# Current player: Terence_Davis
# Current player: Henry_Ellenson
# Current player: Malachi_Flynn
# Current player: Freddie_Gillespie
# Current player: Jalen_Harris
# Current player: Rodney_Hood
# Current player: Stanley_Johnson
# Current player: Alex_Len
# Current player: Kyle_Lowry
# Current player: Patrick_McCaw
# Current player: Norman_Powell
# Current player: Pascal_Siakam
# Current player: Matt_Thomas
# Current player: Gary_Trent_Jr.
# Current player: Fred_VanVleet
# Current player: Yuta_Watanabe
# Current player: Paul_Watson
# Current player: Deni_Avdija
# Current player: Bradley_Beal
# Current player: Jordan_Bell
# Current player: Dāvis_Bertāns
# Current player: Isaac_Bonga
# Current player: Troy_Brown_Jr.
# Current player: Thomas_Bryant
# Current player: Daniel_Gafford
# Current player: Anthony_Gill
# Current player: Rui_Hachimura
# Current player: Chandler_Hutchison
# Current player: Alex_Len
# Current player: Robin_Lopez
# Current player: Garrison_Mathews
# Current player: Raul_Neto
# Current player: Anžejs_Pasečņiks
# Current player: Jerome_Robinson
# Current player: Ish_Smith
# Current player: Moritz_Wagner
# Current player: Russell_Westbrook
# Current player: Cassius_Winston

# %%
os.getcwd()
# Out:
# '/Users/amywinecoff/Documents/CITP/Research/Github/ml-teaching/basketball_reference_scraper'

# %%
nba = pd.DataFrame(columns = ['ast','stl','blk','tov','pf','pts', 
                                             'name', 'position', 'team'])

csv_files = []
os.chdir("/Users/amywinecoff/Documents/CITP/Research/Github/ml-teaching/basketball_reference_scraper/data/players")
for file in glob.glob("*.csv"):
    csv_files.append(file)

for csv in csv_files:
    d = pd.read_csv(csv)
    nba = pd.concat([nba, d], axis=0)
    
nba.to_csv('nba_player_statistics.csv', index=False)
